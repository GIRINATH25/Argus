# %% [markdown]
# <a href="https://colab.research.google.com/github/GIRINATH25/Argus/blob/main/spark_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark import *
from pyspark.sql import *
from pyspark.sql.functions import *


spark = SparkSession.builder \
                    .master("local[*]") \
                    .appName('spark App') \
                    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b3cf25f95a3d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>spark App</code></dd>
#             </dl>
#         </div>
#
#             </div>
